# %%
from datasets import load_dataset

nsfw_ds = load_dataset(
    "vekshinkir/image-censorship-small"
)

print(nsfw_ds)
print(nsfw_ds["train"].features)
print(nsfw_ds["train"][0])
# Out:
# README.md:   0%|          | 0.00/3.19k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# Cell In[12], line 3
#       1 from datasets import load_dataset
# ----> 3 nsfw_ds = load_dataset(
#       4     "vekshinkir/image-censorship-small"
#       5 )
#       7 print(nsfw_ds)
#       8 print(nsfw_ds["train"].features)
#
# File /opt/anaconda3/lib/python3.13/site-packages/datasets/load.py:1696, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1691 verification_mode = VerificationMode(
#    1692     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1693 )
#    1695 # Create a dataset builder
# ...

# %%
print(nsfw_ds)
print(nsfw_ds["train"].features)
print(nsfw_ds["train"][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image'],
#         num_rows: 604
#     })
# })
# {'image': Image(mode=None, decode=True)}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4000x2670 at 0x17E1DFA10>}

# %%
print(nsfw_ds["train"][0]["image"])
print(nsfw_ds["train"].info)
for i in range(5):
    print(i, nsfw_ds["train"][i]["image"].size)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4000x2670 at 0x31CECBB10>
# DatasetInfo(features={'image': Image(mode=None, decode=True)}, builder_name='imagefolder', dataset_name='nsfw-image-classification', config_name='default', version=0.0.0, splits={'train': SplitInfo(name='train', num_bytes=106776, num_examples=604, dataset_name='nsfw-image-classification')}, download_size=167922495, dataset_size=106776, size_in_bytes=168029271)
# 0 (4000, 2670)
# 1 (1024, 768)
# 2 (1280, 834)
# 3 (1280, 720)
# 4 (2666, 4000)

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Display a few images
fig, axes = plt.subplots(2, 3, figsize=(12, 8))

for i, ax in enumerate(axes.flat):
    if i < len(nsfw_ds["train"]):
        img = nsfw_ds["train"][i]["image"]
        ax.imshow(img)
        ax.set_title(f"Image {i}")
    ax.axis("off")

plt.show()
